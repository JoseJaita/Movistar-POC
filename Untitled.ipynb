# %%
# Nativos
import random as rn
import os
import sys
import gc

#calculo
import numpy as np
import pandas as pd
import scipy

#grafico
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
# %matplotlib inline
sns.set(style="whitegrid")

#warning ignore future
import warnings
# warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")
gc.collect()

SEED = 29082013
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
rn.seed(SEED)

# %%
read_parameters = {
    'sep': '\t',
    'header': None,
}

col_date = 21
col_value = 20
col_item_id = 3

# %% [markdown]
# # las columnas de la data no estan ordenadas por fecha y hora, estan ordenadas por item id.
# # Esto quieres decir por ejemplo que las primeras 10000 columnas pertenece al item fileSystem, reportado cada 1 minuto
# # las siguiente 10000 columnas pertenece a la memoria RAM, igualmente cada 1 minutos
# # Ahora los diferentes items id, no se reportan todos en un mismo instante, sino con un desfase de 1 segundo.
# # por ejemplo obtenemos fileSystem en el tiempo 00:00:01 y RamMemory en 00:00:02 y asi sucesivamente
# # pero si nuestro intervalo de tiempo menor es 1 minuto, no hay problema porque en ese lapso ya se habran registrado todos los items-id,

# %%
#file = 'POC_SUN6C52_Reporte 394438.csv'
file_report_sun6c52 = 'POC_SUN6C52_Reporte 396484.csv'
file_report_prd01bl = 'POC_PRD01BL_Reporte 323260.csv'
file_incidentes = 'Lista de Incidencias - Diciembre - Enero.xlsx'

# %%
def read_incidencias(excel_name):
    data = pd.read_excel(excel_name)
    
    data['tiempo'] = data['FECHA DE INICIO'].astype(str) + ' ' + data['HORA DE INICIO'].astype(str)
    data['tiempo'] = pd.to_datetime(
        data['tiempo'], 
    )
    
    data = data.sort_values(by=['tiempo'])
    data.set_index('tiempo', inplace=True)
    
    data['event'] = 110
    return data


def read_report(csv_name):
    data = pd.read_csv(
        csv_name, **read_parameters
    )
    
    data[col_date] = pd.to_datetime(data[col_date])
    #data = data.sort_values(by=[col_date])
    #data.set_index(col_date, inplace=True)
    
    return data

# %%
data_report_sun6c52 = read_report(file_report_sun6c52)
data_report_prd01bl = read_report(file_report_prd01bl)

data_incidencias = read_incidencias(file_incidentes)

# %%
data_report_sun6c52.head()
# Out:
#       0        1      2       3   4      5   \
# 0  10903  sun6c52  10903  105107   0  10903
# 1  10903  sun6c52  10903  105107   0  10903
# 2  10903  sun6c52  10903  105107   0  10903
# 3  10903  sun6c52  10903  105107   0  10903
# 4  10903  sun6c52  10903  105107   0  10903
#
#                                          6                              7   \
# 0  Processor load (15 min average per core)  system.cpu.load[percpu,avg15]
# 1  Processor load (15 min average per core)  system.cpu.load[percpu,avg15]
# 2  Processor load (15 min average per core)  system.cpu.load[percpu,avg15]
# 3  Processor load (15 min average per core)  system.cpu.load[percpu,avg15]
# 4  Processor load (15 min average per core)  system.cpu.load[percpu,avg15]
#
#    8   9   ...     12   13   14  15   16  \
# 0  1m  1w  ...  23001  619  30d  3s  200
# 1  1m  1w  ...  23001  619  30d  3s  200
# 2  1m  1w  ...  23001  619  30d  3s  200
# 3  1m  1w  ...  23001  619  30d  3s  200
# 4  1m  1w  ...  23001  619  30d  3s  200
#
#                                                   17      18          19  \
# 0  The processor load is calculated as system CPU...  105107  1577739587
# 1  The processor load is calculated as system CPU...  105107  1577739647
# 2  The processor load is calculated as system CPU...  105107  1577739707
# 3  The processor load is calculated as system CPU...  105107  1577739767
# 4  The processor load is calculated as system CPU...  105107  1577739827
#
#        20                  21
# 0  0.4666 2019-12-30 15:59:47
# 1  0.4698 2019-12-30 16:00:47
# 2  0.4781 2019-12-30 16:01:47
# 3  0.4780 2019-12-30 16:02:47
# 4  0.4809 2019-12-30 16:03:47
#
# [5 rows x 22 columns]

# %%
data_report_prd01bl.head()
# Out:
#       0        1      2      3   4      5   \
# 0  10717  prd01bl  10717  86323   0  10717
# 1  10717  prd01bl  10717  86323   0  10717
# 2  10717  prd01bl  10717  86323   0  10717
# 3  10717  prd01bl  10717  86323   0  10717
# 4  10717  prd01bl  10717  86323   0  10717
#
#                                         6                             7   8   \
# 0  Processor load (1 min average per core)  system.cpu.load[percpu,avg1]  1m
# 1  Processor load (1 min average per core)  system.cpu.load[percpu,avg1]  1m
# 2  Processor load (1 min average per core)  system.cpu.load[percpu,avg1]  1m
# 3  Processor load (1 min average per core)  system.cpu.load[percpu,avg1]  1m
# 4  Processor load (1 min average per core)  system.cpu.load[percpu,avg1]  1m
#
#    9   ...     12   13   14  15   16  \
# 0  1w  ...  29736  446  30d  3s  200
# 1  1w  ...  29736  446  30d  3s  200
# 2  1w  ...  29736  446  30d  3s  200
# 3  1w  ...  29736  446  30d  3s  200
# 4  1w  ...  29736  446  30d  3s  200
#
#                                                   17     18          19  \
# 0  The processor load is calculated as system CPU...  86323  1577739583
# 1  The processor load is calculated as system CPU...  86323  1577739643
# 2  The processor load is calculated as system CPU...  86323  1577739703
# 3  The processor load is calculated as system CPU...  86323  1577739763
# 4  The processor load is calculated as system CPU...  86323  1577739823
#
#        20                  21
# 0  0.8962 2019-12-30 15:59:43
# 1  0.9296 2019-12-30 16:00:43
# 2  0.9421 2019-12-30 16:01:43
# 3  0.9100 2019-12-30 16:02:43
# 4  0.9250 2019-12-30 16:03:43
#
# [5 rows x 22 columns]

# %%
data_incidencias.head()
# Out:
#                      ITEM FECHA DE INICIO    DIA        MES HORA DE INICIO  \
# tiempo
# 2019-12-23 00:01:00     1      2019-12-23  lunes  Diciembre       00:01:00
# 2019-12-23 00:04:00     2      2019-12-23  lunes  Diciembre       00:04:00
# 2019-12-23 00:40:00     3      2019-12-23  lunes  Diciembre       00:40:00
# 2019-12-23 01:00:00     4      2019-12-23  lunes  Diciembre       01:00:00
# 2019-12-23 01:08:00     6      2019-12-23  lunes  Diciembre       01:08:00
#
#                     FECHA DE FIN  HORA DE FIN        HORA SOLUCION  \
# tiempo
# 2019-12-23 00:01:00   2019-12-25     04:33:00  1900-01-02 04:32:00
# 2019-12-23 00:04:00   2019-12-23     00:22:00             00:18:00
# 2019-12-23 00:40:00   2019-12-23     04:48:00             04:08:00
# 2019-12-23 01:00:00   2019-12-23     01:04:00             00:04:00
# 2019-12-23 01:08:00   2019-12-23     01:51:00             00:43:00
#
#                     TIPO DE ALERTA CATEGORIA PLATAFORMA         SERVICIO  \
# tiempo
# 2019-12-23 00:01:00            NaN       NaN     ZABBIX  INFRAESTRUCTURA
# 2019-12-23 00:04:00            NaN       NaN    DAEMONS  DAEMONS_SUMMARY
# 2019-12-23 00:40:00            NaN       NaN     ZABBIX  INFRAESTRUCTURA
# 2019-12-23 01:00:00            NaN       NaN     ZABBIX  INFRAESTRUCTURA
# 2019-12-23 01:08:00            NaN       NaN    DAEMONS  DAEMONS_SUMMARY
#
#                             UBICACIÓN DEL PROBLEMA           SERVIDOR  \
# tiempo
# 2019-12-23 00:01:00                        MEMORIA  vmosbcmovilprod01
# 2019-12-23 00:04:00  OPERATIONAL DAEMONS - BILLING            prd01bl
# 2019-12-23 00:40:00                          DISCO    vmadminprod01-1
# 2019-12-23 01:00:00                          DISCO              SUN42
# 2019-12-23 01:08:00       OPERATIONAL DAEMONS - RM            prd01bl
#
#                        TICKET REMEDY           CAUSA DE ALERTA  \
# tiempo
# 2019-12-23 00:01:00  INC000003648704                INCIDENCIA
# 2019-12-23 00:04:00       SIN REMEDY  MANTENIMIENTO PROGRAMADO
# 2019-12-23 00:40:00  INC000003648714                INCIDENCIA
# 2019-12-23 01:00:00  INC000003648844                INCIDENCIA
# 2019-12-23 01:08:00       SIN REMEDY  MANTENIMIENTO PROGRAMADO
#
#                              DETALLE  \
# tiempo
# 2019-12-23 00:01:00  CHECKING EVERIS
# 2019-12-23 00:04:00              EOD
# 2019-12-23 00:40:00  CHECKING EVERIS
# 2019-12-23 01:00:00  CHECKING EVERIS
# 2019-12-23 01:08:00    DAEMON BOUNCE
#
#                                                            OBSERVACION  event
# tiempo
# 2019-12-23 00:01:00          Memoria: % de uso > 95% vmosbcmovilprod01    110
# 2019-12-23 00:04:00                           MANTENIMIENTO PROGRAMADO    110
# 2019-12-23 00:40:00  Free disk space is less than 10% on volume /u0...    110
# 2019-12-23 01:00:00  Free disk space is less than 10% on volume /sa...    110
# 2019-12-23 01:08:00                           MANTENIMIENTO PROGRAMADO    110

# %% [markdown]
# # filtrar la data en las incidencias por servidores, en este caso trabajamos con 2. SUN6C52 Y PRD01BL

# %%
data_inci_sun6c52 = data_incidencias[data_incidencias.SERVIDOR == 'sun6c52']
data_inci_prd01bl = data_incidencias[data_incidencias.SERVIDOR == 'prd01bl']

data_inci_sun6c52_zabbix = data_inci_sun6c52[data_inci_sun6c52.PLATAFORMA == 'ZABBIX']
data_inci_prd01bl_zabbix = data_inci_prd01bl[data_inci_prd01bl.PLATAFORMA == 'ZABBIX']

# %%
print(data_inci_sun6c52.shape)
print(data_inci_prd01bl.shape)

print(data_inci_sun6c52_zabbix.shape)
print(data_inci_prd01bl_zabbix.shape)
# Out:
# (124, 19)
# (146, 19)
# (118, 19)
# (11, 19)

# %%
data_inci_sun6c52_zabbix.head()
# Out:
#                      ITEM FECHA DE INICIO    DIA        MES HORA DE INICIO  \
# tiempo
# 2019-12-23 04:36:00    27      2019-12-23  lunes  Diciembre       04:36:00
# 2019-12-23 04:59:00    28      2019-12-23  lunes  Diciembre       04:59:00
# 2019-12-23 05:31:00    30      2019-12-23  lunes  Diciembre       05:31:00
# 2019-12-23 07:51:00    40      2019-12-23  lunes  Diciembre       07:51:00
# 2019-12-23 23:56:00    98      2019-12-23  lunes  Diciembre       23:56:00
#
#                     FECHA DE FIN  HORA DE FIN HORA SOLUCION TIPO DE ALERTA  \
# tiempo
# 2019-12-23 04:36:00   2019-12-23     04:44:00      00:08:00            NaN
# 2019-12-23 04:59:00   2019-12-23     05:11:00      00:12:00            NaN
# 2019-12-23 05:31:00   2019-12-23     05:45:00      00:14:00            NaN
# 2019-12-23 07:51:00   2019-12-23     07:55:00      00:04:00            NaN
# 2019-12-23 23:56:00   2019-12-24     00:05:00      00:09:00            NaN
#
#                     CATEGORIA PLATAFORMA  SERVICIO UBICACIÓN DEL PROBLEMA  \
# tiempo
# 2019-12-23 04:36:00       NaN     ZABBIX  PROCESOS               PROCESOS
# 2019-12-23 04:59:00       NaN     ZABBIX  PROCESOS               PROCESOS
# 2019-12-23 05:31:00       NaN     ZABBIX  PROCESOS               PROCESOS
# 2019-12-23 07:51:00       NaN     ZABBIX  PROCESOS               PROCESOS
# 2019-12-23 23:56:00       NaN     ZABBIX  PROCESOS               PROCESOS
#
#                     SERVIDOR    TICKET REMEDY CAUSA DE ALERTA  \
# tiempo
# 2019-12-23 04:36:00  sun6c52  INC000003649547      INCIDENCIA
# 2019-12-23 04:59:00  sun6c52  INC000003649548      INCIDENCIA
# 2019-12-23 05:31:00  sun6c52  INC000003649847      INCIDENCIA
# 2019-12-23 07:51:00  sun6c52  INC000003650312      INCIDENCIA
# 2019-12-23 23:56:00  sun6c52  INC000003654898      INCIDENCIA
#
#                                   DETALLE  \
# tiempo
# 2019-12-23 04:36:00  CHECKING EVERIS UNIX
# 2019-12-23 04:59:00       CHECKING EVERIS
# 2019-12-23 05:31:00       CHECKING EVERIS
# 2019-12-23 07:51:00       CHECKING EVERIS
# 2019-12-23 23:56:00       CHECKING EVERIS
#
#                                                            OBSERVACION  event
# tiempo
# 2019-12-23 04:36:00  No hay procesos gpiwcms009.4ge por mas de 15 M...    110
# 2019-12-23 04:59:00  No hay procesos gpiwcms009.4ge por mas de 15 M...    110
# 2019-12-23 05:31:00  No hay procesos gpiwcms009.4ge por mas de 15 M...    110
# 2019-12-23 07:51:00  No hay procesos gpiwcms009.4ge por mas de 15 M...    110
# 2019-12-23 23:56:00  No hay procesos gpiwcms009.4ge por mas de 15 M...    110

# %% [markdown]
# # ahora obtendremos un dictionary por cada servidor, donde key=item_id y value=DataFrame order by DateTime

# %%
def get_indexs(data_report):
    items_id = data_report[col_item_id][:].tolist()
    items_id_dict = {}
    
    cambios = []
    items = []
    for i,item in enumerate(items_id):
        if item in items_id_dict.keys(): 
            items_id_dict[item] = items_id_dict[item] + 1
        else:
            items_id_dict[item] = 1
            cambios.append(i)
            items.append(item)
            
    return items

# %%
data_report_list = [data_report_sun6c52, data_report_prd01bl]
data_report_list_dict = []

# %%
for _data in data_report_list:
    items_id = get_indexs(_data)
    
    print(items_id)
    dict1 = {}
    for _item_id in items_id:
        filtro = _data[col_item_id] == _item_id
        df = _data[filtro]
        dict1[_item_id] = df

    data_report_list_dict.append(dict1)
# Out:
# [105107, 105108, 105109, 105111, 105112, 105113, 105114, 105118, 105326, 105327, 172755, 105328, 105329, 105330, 105331, 105332, 105333, 105334, 105335, 105336, 105337, 105338, 114466, 105352, 105353, 172757, 105354, 105355, 105356, 105357, 105358, 105359, 105360, 105361, 105362, 105363, 105364, 114468, 105125]
# [86323, 86328, 86339, 86869, 86870, 86871, 86872, 86882, 86873, 86879, 86880, 86875, 86881, 86874, 86876, 86877, 86878, 86897, 86898, 86899, 86900, 86910, 86901, 86907, 86908, 86903, 86909, 86902, 86904, 86905, 86906, 86346]

# %%
#b = data_inci_sun6c52_zabbix.iloc[0:30].copy()

#b.head()

#b.plot.axvline(color='k', linestyle='--')
#b.plot(y='event',kind='bar')
#b['event'].plot.bar()

# %%
#for date in data_inci_sun6c52_zabbix.iloc[0:10].index:
#    print(date)

# %%
# %matplotlib qt
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(20, 30))
# plot the differents items wrt to index for default
for _item in data_report_list_dict[0].keys():
    data_report_list_dict[0][_item][col_value][:].plot(ax=axes[0])

    
# plot the differents items wrt to DateTime
#ax = plt.plot()
for _item in data_report_list_dict[0].keys():
    _df = data_report_list_dict[0][_item].copy()
    _df.set_index(col_date, inplace=True)

    _df[col_value][:].plot(ax=axes[1])

#axes[1].axvline(data_inci_sun6c52_zabbix, color='r', linestyle='--', lw=2)

#for date in data_inci_sun6c52_zabbix.index:
#    axes[1].axvline(date, color="red", linestyle="--")

# %% [markdown]
# # plot las diferentes metricas desplazadas unas de otras

# %%
# para el servidor SUN6C52
ax = None
for _item in data_report_list_dict[0].keys():
    if ax == None: ax = data_report_list_dict[0][_item][col_value][:].plot()
    else: data_report_list_dict[0][_item][col_value][:].plot(ax=ax,color='red')
        
for _item in data_report_list_dict[1].keys():
    if ax == None: ax = data_report_list_dict[1][_item][col_value][:].plot()
    else: data_report_list_dict[1][_item][col_value][:].plot(ax=ax, color='blue')

# %%
# para el servidor PRD01BL
ax = None
for _item in data_report_list_dict[1].keys():
    if ax == None: ax = data_report_list_dict[1][_item][col_value][:].plot()
    else: ax = data_report_list_dict[1][_item][col_value][:].plot()

# %% [markdown]
# # plot las metricas con respecto al tiempo, ademas se indica donde ocurrio un evento

# %%
ax = None
for _item in data_report_list_dict[0].keys():
    _df = data_report_list_dict[0][_item].copy()
    _df.set_index(col_date, inplace=True)

    if ax == None: ax = _df[col_value][:].plot()
    else: _df[col_value][:].plot(ax=ax)
#axes[1].axvline(data_inci_sun6c52_zabbix, color='r', linestyle='--', lw=2)

# plot alertas hechas por el ZABBIX
for date in data_inci_sun6c52_zabbix.index:
    ax.axvline(date, color="red", linestyle="--", lw=2)
    
# plot aleartas hechas por otras plataformas
aux = data_inci_sun6c52[data_inci_sun6c52.PLATAFORMA != 'ZABBIX']
for date in aux.index:
    ax.axvline(date, color="blue", linestyle="--", lw=2)

# %%
ax = None
for _item in data_report_list_dict[1].keys():
    _df = data_report_list_dict[1][_item].copy()
    _df.set_index(col_date, inplace=True)

    if ax == None: ax = _df[col_value][:].plot()
    else: _df[col_value][:].plot(ax=ax)
#axes[1].axvline(data_inci_sun6c52_zabbix, color='r', linestyle='--', lw=2)

# plot alertas hechas por el ZABBIX
for date in data_inci_prd01bl_zabbix.index:
    ax.axvline(date, color="red", linestyle="--", lw=2)
    
# plot aleartas hechas por otras plataformas
aux = data_inci_prd01bl[data_inci_prd01bl.PLATAFORMA != 'ZABBIX']
for date in aux.index:
    ax.axvline(date, color="blue", linestyle="--", lw=2)

# %%
a = data_report_sun6c52.copy()
a = a.sort_values(by=[col_date])
a.set_index(col_date, inplace=True)

# %%
a.head()
# Out:
#                         0        1      2       3   4      5   \
# 21
# 2019-12-30 15:59:17  10903  sun6c52  10903  172757   0  10903
# 2019-12-30 15:59:26  10903  sun6c52  10903  105326   0  10903
# 2019-12-30 15:59:27  10903  sun6c52  10903  105327   0  10903
# 2019-12-30 15:59:28  10903  sun6c52  10903  105328   0  10903
# 2019-12-30 15:59:29  10903  sun6c52  10903  105329   0  10903
#
#                                                            6   \
# 21
# 2019-12-30 15:59:17   Free disk space on /backup (percentage)
# 2019-12-30 15:59:26             Free inodes on / (percentage)
# 2019-12-30 15:59:27   Free inodes on /agcloud13c (percentage)
# 2019-12-30 15:59:28  Free inodes on /export/home (percentage)
# 2019-12-30 15:59:29     Free inodes on /informix (percentage)
#
#                                                    7   8   9   ... 11  12  \
# 21                                                             ...
# 2019-12-30 15:59:17        vfs.fs.size[/backup,pfree]  1m  1w  ...  %  \N
# 2019-12-30 15:59:26             vfs.fs.inode[/,pfree]  1m  1w  ...  %  \N
# 2019-12-30 15:59:27   vfs.fs.inode[/agcloud13c,pfree]  1m  1w  ...  %  \N
# 2019-12-30 15:59:28  vfs.fs.inode[/export/home,pfree]  1m  1w  ...  %  \N
# 2019-12-30 15:59:29     vfs.fs.inode[/informix,pfree]  1m  1w  ...  %  \N
#
#                       13   14  15   16   17      18          19       20
# 21
# 2019-12-30 15:59:17  619  30d  3s  200  NaN  172757  1577739557  37.6396
# 2019-12-30 15:59:26  619  30d  3s  200  NaN  105326  1577739566  87.9358
# 2019-12-30 15:59:27  619  30d  3s  200  NaN  105327  1577739567  99.9976
# 2019-12-30 15:59:28  619  30d  3s  200  NaN  105328  1577739568  38.2369
# 2019-12-30 15:59:29  619  30d  3s  200  NaN  105329  1577739569  73.0958
#
# [5 rows x 21 columns]

# %%
items_id = data_report_sun6c52[3][:].tolist()
items_id_dict = {}

# %%
antiguo = -1
cambios = []
for i,item in enumerate(items_id):
    if item in items_id_dict.keys(): 
        items_id_dict[item] = items_id_dict[item] + 1
    else:
        items_id_dict[item] = 1
        cambios.append(i)
    #if item != antiguo: print(i)
    #antiguo = item

# %%
print("numero de items_id : {}".format(len(items_id_dict.keys())))
# Out:
# numero de items_id : 39

# %%
# %matplotlib inline
for i in range(1,39):
    y = data_report_sun6c52[col_value][cambios[i-1]:cambios[i]].tolist()
    x = np.arange(len(y))
    plt.plot(x[0:2000], y[0:2000])

# %%
# Out:
# numero de items_id : 39

# %%
# %matplotlib inline
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(20, 30))
data[col_item_id].plot(ax=axes[0])
data[col_value].plot(ax=axes[1])
